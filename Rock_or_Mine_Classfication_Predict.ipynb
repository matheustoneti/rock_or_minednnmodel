# %% [markdown]
# <a href="https://colab.research.google.com/github/matheustoneti/rock_or_minednnmodel/blob/main/Rock_or_Mine_Classfication_Predict.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

# %%
data = pd.read_csv('ROCK_OR_MINE.csv')

# %%
y = data['R']
x = data.drop(['R'], axis=1)

# %%
le = preprocessing.LabelEncoder()

# %%
y = le.fit_transform(y)

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=(0.3))

# %%
from sklearn.metrics import accuracy_score
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout

# %%
model = Sequential()

# %%
model.add(Dense(units=32, activation='relu', input_dim=len(x_train.columns)))
model.add(Dense(units=128, activation='relu'))
model.add(Dense(units=1, activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics='accuracy')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 32)                1952
#
#  dense_1 (Dense)             (None, 128)               4224
#
#  dense_2 (Dense)             (None, 1)                 129
#
# ...
# Total params: 6,305
# Trainable params: 6,305
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(x_train, y_train, epochs=1000, batch_size=32, verbose=2)
# Out:
# Epoch 1/1000
# 5/5 - 0s - loss: 0.7044 - accuracy: 0.4375 - 391ms/epoch - 78ms/step
# Epoch 2/1000
# 5/5 - 0s - loss: 0.6874 - accuracy: 0.5556 - 10ms/epoch - 2ms/step
# Epoch 3/1000
# 5/5 - 0s - loss: 0.6753 - accuracy: 0.5625 - 9ms/epoch - 2ms/step
# Epoch 4/1000
# 5/5 - 0s - loss: 0.6696 - accuracy: 0.5972 - 10ms/epoch - 2ms/step
# Epoch 5/1000
# 5/5 - 0s - loss: 0.6598 - accuracy: 0.6250 - 11ms/epoch - 2ms/step
# Epoch 6/1000
# 5/5 - 0s - loss: 0.6530 - accuracy: 0.6319 - 17ms/epoch - 3ms/step
# Epoch 7/1000
# 5/5 - 0s - loss: 0.6451 - accuracy: 0.6458 - 16ms/epoch - 3ms/step
# Epoch 8/1000
# 5/5 - 0s - loss: 0.6367 - accuracy: 0.6667 - 10ms/epoch - 2ms/step
# Epoch 9/1000
# 5/5 - 0s - loss: 0.6274 - accuracy: 0.6875 - 11ms/epoch - 2ms/step
# Epoch 10/1000
# 5/5 - 0s - loss: 0.6177 - accuracy: 0.7014 - 10ms/epoch - 2ms/step
# Epoch 11/1000
# 5/5 - 0s - loss: 0.6072 - accuracy: 0.7153 - 9ms/epoch - 2ms/step
# Epoch 12/1000
# ...

# %%
y_hat = model.predict(x_test)
# Out:
# 2/2 [==============================] - 0s 3ms/step

# %%
results = []
for valor in y_hat:
  if valor < 0.5:
    var = 0
  else:
    var = 1
  results.append(var)

# %%
results = np.array(results)

# %%
accuracy_score = accuracy_score (y_test, results)

# %%
print('Accuracy with Deep Learning:', accuracy_score)
# Out:
# Accuracy with Deep Learning: 0.873015873015873

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
model_ml = GradientBoostingClassifier()

# %%
model_ml = model_ml.fit(x_train,y_train)

# %%
score = model_ml.score(x_test, y_test)

# %%
print('Accuracy with GradientBoosting:', score)
# Out:
# Accuracy with GradientBoosting: 0.7619047619047619
